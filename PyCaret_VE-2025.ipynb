# %%
import pandas as pd

caminho = r"C:\Users\user\PrevisãoVE2025\dados_VEs_porMunicipio2025.csv"
dataset = pd.read_csv(caminho, sep=',', dtype={"Cod_municipio": "int64"})

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Nome_UF                          14640 non-null  object
#  1   Nome_Município                   14640 non-null  object
#  2   Tipo_de_VE                       14640 non-null  object
#  3   Qtd. Veículos                    14640 non-null  int64
#  4   Cod_municipio                    14640 non-null  int64
#  5   Ano                              14640 non-null  int64
#  6   Potencia_instalada_fotovoltaica  14640 non-null  float64
#  7   Tarifa_eletrica                  14640 non-null  float64
#  8   Densidade_demo                   14640 non-null  float64
#  9   Frota                            14640 non-null  float64
#  10  Num_medio_salariosMin            14640 non-null  float64
#  11  Num_empregados                   14640 non-null  int64
#  12  Num_empresas                     14640 non-null  int64
#  13  PIB                              14640 non-null  object
#  14  Populacao                        14640 non-null  float64
#  15  Area                             14640 non-null  float64
#  16  IDH_educacao                     14640 non-null  float64
#  17  IDH_saude                        14640 non-null  float64
#  18  IDH_renda                        14640 non-null  float64
#  19  Educacao_superior                14640 non-null  float64
#  20  Irradiancia                      14640 non-null  float64
#  21  Num_familias                     14640 non-null  float64
#  22  Verticalizacao_cidades           14640 non-null  float64
#  23  Familias_area_rural              14640 non-null  float64
#  24  Casas_proprias                   14640 non-null  float64
#  25  Casas_alugadas                   14640 non-null  float64
#  26  Residentes_por_familia           14640 non-null  float64
#  27  Familias_mais_3_salarios         14640 non-null  float64
# dtypes: float64(19), int64(5), object(4)
# memory usage: 3.1+ MB

# %%
dataset.columns
# Out:
# Index(['Nome_UF', 'Nome_Município', 'Tipo_de_VE', 'Qtd. Veículos',
#        'Cod_municipio', 'Ano', 'Potencia_instalada_fotovoltaica',
#        'Tarifa_eletrica', 'Densidade_demo', 'Frota', 'Num_medio_salariosMin',
#        'Num_empregados', 'Num_empresas', 'PIB', 'Populacao', 'Area',
#        'IDH_educacao', 'IDH_saude', 'IDH_renda', 'Educacao_superior',
#        'Irradiancia', 'Num_familias', 'Verticalizacao_cidades',
#        'Familias_area_rural', 'Casas_proprias', 'Casas_alugadas',
#        'Residentes_por_familia', 'Familias_mais_3_salarios'],
#       dtype='object')

# %%
dataset[dataset['PIB'] == '#DIV/0!'] # razão pela qual o PIB foi interpretado como object e não como numérico
# Out:
#                   Nome_UF Nome_Município                Tipo_de_VE  \
# 13399  MATO GROSSO DO SUL      FIGUEIRAO           DIESEL/ELETRICO
# 13400  MATO GROSSO DO SUL      FIGUEIRAO    ELETRICO/FONTE EXTERNA
# 13401  MATO GROSSO DO SUL      FIGUEIRAO  GASOLINA/ALCOOL/ELETRICO
# 13402  MATO GROSSO DO SUL      FIGUEIRAO           HIBRIDO PLUG-IN
#
#        Qtd. Veículos  Cod_municipio   Ano  Potencia_instalada_fotovoltaica  \
# 13399              1        5003900  2024                           806.02
# 13400              1        5003900  2024                           806.02
# 13401              1        5003900  2024                           806.02
# 13402              1        5003900  2024                           806.02
#
#        Tarifa_eletrica  Densidade_demo   Frota  ...  IDH_renda  \
# 13399       873.322404            0.73  1456.0  ...      0.677
# 13400       873.322404            0.73  1456.0  ...      0.677
# 13401       873.322404            0.73  1456.0  ...      0.677
# 13402       873.322404            0.73  1456.0  ...      0.677
#
#        Educacao_superior  Irradiancia Num_familias  Verticalizacao_cidades  \
# 13399              0.036       5233.0       1363.0                0.000734
# 13400              0.036       5233.0       1363.0                0.000734
# 13401              0.036       5233.0       1363.0                0.000734
# 13402              0.036       5233.0       1363.0                0.000734
#
#        Familias_area_rural  Casas_proprias  Casas_alugadas  \
# 13399             0.428467         0.41526        0.082172
# 13400             0.428467         0.41526        0.082172
# 13401             0.428467         0.41526        0.082172
# 13402             0.428467         0.41526        0.082172
#
#        Residentes_por_familia  Familias_mais_3_salarios
# 13399                    2.59                  0.029347
# 13400                    2.59                  0.029347
# 13401                    2.59                  0.029347
# 13402                    2.59                  0.029347
#
# [4 rows x 28 columns]

# %%
# prompt: coloque o valor 46773.62 como o PIB do município de código 5003900

import pandas as pd
# It looks like there is an issue with assignment. Let's try using .loc to set the value.
# We also need to ensure the 'PIB' column is of a numeric type before assigning a float.
# Let's first convert the 'PIB' column to numeric, handling errors by coercing to NaN,
# and then fill the specific value using .loc
# Before converting, let's replace the '#DIV/0!' string with a value that can be coerced to NaN
dataset['PIB'] = dataset['PIB'].replace('#DIV/0!', pd.NA)

# Now convert the 'PIB' column to numeric
dataset['PIB'] = pd.to_numeric(dataset['PIB'], errors='coerce')

# Use .loc to assign the value based on the condition
dataset.loc[dataset['Cod_municipio'] == 5003900, 'PIB'] = 46773.62  # PIB de 2021 pelo IBGE que peguei no site.

# %%
dataset[dataset['Cod_municipio'] == 5003900]['PIB']
# Out:
# 13399    46773.62
# 13400    46773.62
# 13401    46773.62
# 13402    46773.62
# Name: PIB, dtype: float64

# %%
dataset.info() # agora sim, a princípio, todas as features interpretadas com o tipo correto de dado.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Nome_UF                          14640 non-null  object
#  1   Nome_Município                   14640 non-null  object
#  2   Tipo_de_VE                       14640 non-null  object
#  3   Qtd. Veículos                    14640 non-null  int64
#  4   Cod_municipio                    14640 non-null  int64
#  5   Ano                              14640 non-null  int64
#  6   Potencia_instalada_fotovoltaica  14640 non-null  float64
#  7   Tarifa_eletrica                  14640 non-null  float64
#  8   Densidade_demo                   14640 non-null  float64
#  9   Frota                            14640 non-null  float64
#  10  Num_medio_salariosMin            14640 non-null  float64
#  11  Num_empregados                   14640 non-null  int64
#  12  Num_empresas                     14640 non-null  int64
#  13  PIB                              14640 non-null  float64
#  14  Populacao                        14640 non-null  float64
#  15  Area                             14640 non-null  float64
#  16  IDH_educacao                     14640 non-null  float64
#  17  IDH_saude                        14640 non-null  float64
#  18  IDH_renda                        14640 non-null  float64
#  19  Educacao_superior                14640 non-null  float64
#  20  Irradiancia                      14640 non-null  float64
#  21  Num_familias                     14640 non-null  float64
#  22  Verticalizacao_cidades           14640 non-null  float64
#  23  Familias_area_rural              14640 non-null  float64
#  24  Casas_proprias                   14640 non-null  float64
#  25  Casas_alugadas                   14640 non-null  float64
#  26  Residentes_por_familia           14640 non-null  float64
#  27  Familias_mais_3_salarios         14640 non-null  float64
# dtypes: float64(20), int64(5), object(3)
# memory usage: 3.1+ MB

# %%
# prompt: transforme o dataset de forma que cada linha seja um município e a quantidade de veículos represente a soma de todos os tipos de veículos, mantenha todas as colunas.

# Agrupar por município e somar a quantidade de veículos
dataset_agrupado = dataset.groupby('Cod_municipio').agg({ # funciona bem porque cada município tem um código único do IBGE
    'Nome_UF': 'first',
    'Nome_Município': 'first',      # Pq eu posso pegar a primeira ocorrência de todos, exceto o Cod_municipio?
    'Tipo_de_VE': 'first',          # Pois as demais colunas tem dados repetidos em função do Tipo_de_VE. Estamos considerando todos os tipos como "eletrico"
    'Qtd. Veículos': 'sum', # soma as quantidade por City_Cod
    'Ano': 'first',
    'Potencia_instalada_fotovoltaica': 'first',
    'Tarifa_eletrica': 'first',
    'Densidade_demo': 'first',
    'Frota': 'first',
    'Num_medio_salariosMin': 'first',
    'Num_empregados': 'first',
    'Num_empresas': 'first',
    'PIB': 'first',
    'Populacao': 'first',
    'Area': 'first',
    'IDH_educacao': 'first',
    'IDH_saude': 'first',
    'IDH_renda': 'first',
    'Educacao_superior': 'first',
    'Irradiancia': 'first',
    'Num_familias': 'first',
    'Verticalizacao_cidades': 'first',
    'Familias_area_rural': 'first',
    'Casas_proprias': 'first',
    'Casas_alugadas': 'first',
    'Residentes_por_familia': 'first',
    'Familias_mais_3_salarios': 'first'
}).reset_index()

# Exibir o dataset transformado
print(dataset_agrupado.head())
dataset_agrupado.info()
# Out:
#    Cod_municipio   Nome_UF         Nome_Município              Tipo_de_VE  \
# 0        1100015  RONDONIA  ALTA FLORESTA D'OESTE  ELETRICO/FONTE EXTERNA
# 1        1100023  RONDONIA              ARIQUEMES         DIESEL/ELETRICO
# 2        1100031  RONDONIA                 CABIXI       GASOLINA/ELETRICO
# 3        1100049  RONDONIA                 CACOAL                ELETRICO
# 4        1100056  RONDONIA             CEREJEIRAS  ELETRICO/FONTE EXTERNA
#
#    Qtd. Veículos   Ano  Potencia_instalada_fotovoltaica  Tarifa_eletrica  \
# 0             11  2024                          3467.06       686.555813
# 1            217  2024                         28751.08       686.555813
# 2              1  2024                          1322.32       686.555813
# 3            178  2024                         25024.72       686.555813
# 4             15  2024                          4588.86       686.555813
#
#    Densidade_demo    Frota  ...  IDH_renda  Educacao_superior  Irradiancia  \
# 0            3.04  16100.0  ...      0.657              0.036       4635.0
# 1           21.88  82721.0  ...      0.716              0.039       4494.0
# 2            4.07   4039.0  ...      0.650              0.038       4795.0
# 3           22.91  75559.0  ...      0.727              0.047       4622.0
# 4            5.71  13012.0  ...      0.688              0.048       4767.0
#
#    Num_familias  Verticalizacao_cidades  Familias_area_rural  Casas_proprias  \
# 0        7695.0                0.001689             0.375049        0.697076
# 1       34768.0                0.062069             0.126754        0.515905
# 2        1967.0                0.001525             0.456533        0.764616
# 3       31917.0                0.078986             0.162860        0.507660
# 4        5873.0                0.009705             0.106419        0.674102
#
#    Casas_alugadas  Residentes_por_familia  Familias_mais_3_salarios
# 0        0.106823                    2.79                  0.030669
# 1        0.182984                    2.77                  0.053325
# 2        0.075750                    2.72                  0.030503
# 3        0.167309                    2.71                  0.052668
# 4        0.132641                    2.69                  0.044951
#
# [5 rows x 28 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4483 entries, 0 to 4482
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Cod_municipio                    4483 non-null   int64
#  1   Nome_UF                          4483 non-null   object
#  2   Nome_Município                   4483 non-null   object
#  3   Tipo_de_VE                       4483 non-null   object
#  4   Qtd. Veículos                    4483 non-null   int64
#  5   Ano                              4483 non-null   int64
#  6   Potencia_instalada_fotovoltaica  4483 non-null   float64
#  7   Tarifa_eletrica                  4483 non-null   float64
#  8   Densidade_demo                   4483 non-null   float64
#  9   Frota                            4483 non-null   float64
#  10  Num_medio_salariosMin            4483 non-null   float64
#  11  Num_empregados                   4483 non-null   int64
#  12  Num_empresas                     4483 non-null   int64
#  13  PIB                              4483 non-null   float64
#  14  Populacao                        4483 non-null   float64
#  15  Area                             4483 non-null   float64
#  16  IDH_educacao                     4483 non-null   float64
#  17  IDH_saude                        4483 non-null   float64
#  18  IDH_renda                        4483 non-null   float64
#  19  Educacao_superior                4483 non-null   float64
#  20  Irradiancia                      4483 non-null   float64
#  21  Num_familias                     4483 non-null   float64
#  22  Verticalizacao_cidades           4483 non-null   float64
#  23  Familias_area_rural              4483 non-null   float64
#  24  Casas_proprias                   4483 non-null   float64
#  25  Casas_alugadas                   4483 non-null   float64
#  26  Residentes_por_familia           4483 non-null   float64
#  27  Familias_mais_3_salarios         4483 non-null   float64
# dtypes: float64(20), int64(5), object(3)
# memory usage: 980.8+ KB

# %%
# a partir deste ponto é que eu posso começar a brincar  para treinar os algoritmos.
# Afinal, é neste ponto que o dataset está pronto, ou seja, cada linha está por município.

# %%
# %pip install pycaret
# Out:
# Requirement already satisfied: pycaret in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.11/dist-packages (from pycaret) (7.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in /usr/local/lib/python3.11/dist-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from pycaret) (2.0.7)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.13.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.11/dist-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (5.9.5)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.11/dist-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from pycaret) (1.2.0)
# Requirement already satisfied: schemdraw==0.15 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.14.5)
# Requirement already satisfied: sktime==0.26.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from pycaret) (2.0.4)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from sktime==0.26.0->pycaret) (24.2)
# Requirement already satisfied: scikit-base<0.8.0 in /usr/local/lib/python3.11/dist-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category-encoders>=2.4.0->pycaret) (1.0.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn>=0.12.0->pycaret) (0.1.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn>=0.12.0->pycaret) (3.6.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.0.15)
# Requirement already satisfied: choreographer>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from kaleido>=0.2.1->pycaret) (1.2.1)
# Requirement already satisfied: logistro>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.11/dist-packages (from kaleido>=0.2.1->pycaret) (3.10.18)
# Requirement already satisfied: pytest-timeout>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret) (4.24.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret) (5.8.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.14.0->pycaret) (8.5.0)
# Requirement already satisfied: dash>=2.11.0 in /usr/local/lib/python3.11/dist-packages (from plotly-resampler>=0.8.3.1->pycaret) (4.0.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima>=2.0.4->pycaret) (3.0.12)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pmdarima>=2.0.4->pycaret) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret) (2025.7.14)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.11/dist-packages (from choreographer>=1.1.1->kaleido>=0.2.1->pycaret) (3.20.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.1)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.11/dist-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.3)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.14.1)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: pytest>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (8.3.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.7)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (25.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.3.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.3.1)

# %% [markdown]
# **Faz sentido remover Nome_UF? Provavelmente não. É recomendado manter.**
#
# - Motivo: A UF (Estado) é uma variável categórica com um número gerenciável de categorias (27 no Brasil). Fatores como políticas estaduais, desenvolvimento econômico regional, densidade populacional e infraestrutura podem variar significativamente entre UFs e influenciar a quantidade de veículos elétricos.
#
# - **atualização:** fiz um teste deixando Nome_UF acontece um One_hot_enconding e passamos a ter 27 variáveis. O Distrito Federal (por ser estado e município) acaba dominando, o que não faz sentido. **Portanto, decidi remover a coluna Nome_UF.**

# %%
from pycaret.regression import *

# Setup PyCaret for regression
s = setup(dataset_agrupado,
          target = 'Qtd. Veículos',
          ignore_features = ['Nome_UF', 'Cod_municipio', 'Nome_Município', 'Tipo_de_VE', 'Ano'],
          #categorical_features = ['Nome_UF'], # Ensure Nome_UF is treated as categorical
          polynomial_features = False,
          polynomial_degree = 2,
          # ignore_low_variance = True, # Useful for numerical features with little variance
          remove_multicollinearity = True, # Useful to remove highly correlated features
          multicollinearity_threshold = 0.9,
          fold_strategy = 'kfold',
          fold = 10, # Default number of folds
          n_jobs = -1, # Use all available cores
          session_id = 123,
          log_experiment = False,
          experiment_name = 'regression_experiment',
          use_gpu = False, # Set to True if you have a compatible GPU
          profile = True, # Generate a profiling report to see memory and CPU usage
          # memory = False, # Optimize memory usage
          # verbose = True, # Display verbose output during setup
          # version = False, # Display PyCaret version
          # early_stopping = False,
          # early_stopping_max_rounds = 10,
          # early_stopping_method = 'caret',
          # calibrate = False,
          # calibrate_method = 'isotonic',
          # fit_kwargs = None,
          # transform_kwargs = None,
          preprocess = True, # Ensure preprocessing is enabled
          # low_variance_threshold = 0.01,
          # numeric_imputation = 'mean',
          # categorical_imputation = 'mode',
          normalize = False,
          # normalize_method = 'zscore',
          # transform_target = False,
          # transform_target_method = 'box-cox',
          # data_split_is_greater_than = 1000,
          # handle_missing_values = True,
          # missing_values_symbol = 'NaN',
          # Iterative Imputation
          # iterative_imputation_iterator = 'lightgbm',
          # iterative_imputation_iters = 10,
          # iterative_imputation_random_state = 123,
          # iterative_imputation_order = 'roman',
          # iterative_imputation_add_indicator = False,
          # iterative_imputation_imputer_list = None,
          max_encoding_ohe = 27 # Set the one-hot encoding limit
          )

# Compare models including specific algorithms
best_model = compare_models(include=['lr', 'lasso', 'ridge', 'en', 'lar', 'llar', 'omp', 'br', 'ard', 'par', 'kr', 'svm', 'knn', 'dt', 'rf', 'et', 'ada', 'gbr', 'mlp', 'xgboost', 'lightgbm'],
                           # Add the specific algorithms you want to include
                           # MLP is 'mlp' (Neural Network)
                           # SVR is 'svm'
                           # XGBoost is 'xgboost'
                           # Other models are added for a more comprehensive comparison
                           # 'lr' (Linear Regression), 'lasso' (Lasso Regression), 'ridge' (Ridge Regression), 'en' (Elastic Net), 'lar' (Least Angle Regression), 'llar' (Lasso Least Angle Regression), 'omp' (Orthogonal Matching Pursuit), 'br' (Bayesian Ridge), 'ard' (Automatic Relevance Determination), 'par' (Passive Aggressive Regressor), 'hr' (Huber Regressor), 'kr' (Kernel Ridge), 'knn' (K Neighbors Regressor), 'dt' (Decision Tree Regressor), 'rf' (Random Forest Regressor), 'et' (Extra Trees Regressor), 'ada' (AdaBoost Regressor), 'gbr' (Gradient Boosting Regressor), 'lightgbm' (Light Gradient Boosting Machine), 'catboost' (CatBoost Regressor)
                           sort = 'RMSE') # Sort by Root Mean Squared Error
# Out:
# <style type="text/css">
# #T_6ca3a_row9_col1, #T_6ca3a_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6ca3a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ca3a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6ca3a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ca3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ca3a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6ca3a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ca3a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6ca3a_row1_col1" class="data row1 col1" >Qtd. Veículos</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ca3a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6ca3a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ca3a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6ca3a_row3_col1" class="data row3 col1" >(4483, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ca3a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6ca3a_row4_col1" class="data row4 col1" >(4483, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ca3a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6ca3a_row5_col1" class="data row5 col1" >(3138, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ca3a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6ca3a_row6_col1" class="data row6 col1" >(1345, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6ca3a_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_6ca3a_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6ca3a_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_6ca3a_row8_col1" class="data row8 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6ca3a_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_6ca3a_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6ca3a_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_6ca3a_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6ca3a_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_6ca3a_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6ca3a_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_6ca3a_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6ca3a_row13_col0" class="data row13 col0" >Remove multicollinearity</td>
#       <td id="T_6ca3a_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6ca3a_row14_col0" class="data row14 col0" >Multicollinearity threshold</td>
#       <td id="T_6ca3a_row14_col1" class="data row14 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6ca3a_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_6ca3a_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6ca3a_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_6ca3a_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6ca3a_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_6ca3a_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6ca3a_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_6ca3a_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6ca3a_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_6ca3a_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6ca3a_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_6ca3a_row20_col1" class="data row20 col1" >regression_experiment</td>
#     </tr>
#     <tr>
#       <th id="T_6ca3a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_6ca3a_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_6ca3a_row21_col1" class="data row21 col1" >d455</td>
#     </tr>
#   </tbody>
# </table>
# Loading profile... Please Wait!
# Profiler Failed. No output to show, continue with modeling.
# <style type="text/css">
# #T_03b26 th {
#   text-align: left;
# }
# #T_03b26_row0_col0, #T_03b26_row0_col1, #T_03b26_row0_col4, #T_03b26_row0_col5, #T_03b26_row0_col6, #T_03b26_row1_col0, #T_03b26_row1_col1, #T_03b26_row1_col2, #T_03b26_row1_col3, #T_03b26_row1_col4, #T_03b26_row1_col5, #T_03b26_row1_col6, #T_03b26_row2_col0, #T_03b26_row2_col1, #T_03b26_row2_col2, #T_03b26_row2_col3, #T_03b26_row2_col4, #T_03b26_row2_col5, #T_03b26_row2_col6, #T_03b26_row3_col0, #T_03b26_row3_col1, #T_03b26_row3_col2, #T_03b26_row3_col3, #T_03b26_row3_col4, #T_03b26_row3_col5, #T_03b26_row3_col6, #T_03b26_row4_col0, #T_03b26_row4_col1, #T_03b26_row4_col2, #T_03b26_row4_col3, #T_03b26_row4_col4, #T_03b26_row4_col5, #T_03b26_row4_col6, #T_03b26_row5_col0, #T_03b26_row5_col1, #T_03b26_row5_col2, #T_03b26_row5_col3, #T_03b26_row5_col4, #T_03b26_row5_col5, #T_03b26_row5_col6, #T_03b26_row6_col0, #T_03b26_row6_col1, #T_03b26_row6_col2, #T_03b26_row6_col3, #T_03b26_row6_col4, #T_03b26_row6_col5, #T_03b26_row6_col6, #T_03b26_row7_col0, #T_03b26_row7_col1, #T_03b26_row7_col2, #T_03b26_row7_col3, #T_03b26_row7_col4, #T_03b26_row7_col5, #T_03b26_row7_col6, #T_03b26_row8_col0, #T_03b26_row8_col1, #T_03b26_row8_col2, #T_03b26_row8_col3, #T_03b26_row8_col4, #T_03b26_row8_col5, #T_03b26_row8_col6, #T_03b26_row9_col0, #T_03b26_row9_col1, #T_03b26_row9_col2, #T_03b26_row9_col3, #T_03b26_row9_col4, #T_03b26_row9_col5, #T_03b26_row9_col6, #T_03b26_row10_col0, #T_03b26_row10_col2, #T_03b26_row10_col3, #T_03b26_row11_col0, #T_03b26_row11_col1, #T_03b26_row11_col2, #T_03b26_row11_col3, #T_03b26_row11_col4, #T_03b26_row11_col5, #T_03b26_row11_col6, #T_03b26_row12_col0, #T_03b26_row12_col1, #T_03b26_row12_col2, #T_03b26_row12_col3, #T_03b26_row12_col4, #T_03b26_row12_col5, #T_03b26_row12_col6, #T_03b26_row13_col0, #T_03b26_row13_col1, #T_03b26_row13_col2, #T_03b26_row13_col3, #T_03b26_row13_col4, #T_03b26_row13_col5, #T_03b26_row13_col6, #T_03b26_row14_col0, #T_03b26_row14_col1, #T_03b26_row14_col2, #T_03b26_row14_col3, #T_03b26_row14_col4, #T_03b26_row14_col5, #T_03b26_row14_col6, #T_03b26_row15_col0, #T_03b26_row15_col1, #T_03b26_row15_col2, #T_03b26_row15_col3, #T_03b26_row15_col4, #T_03b26_row15_col5, #T_03b26_row15_col6, #T_03b26_row16_col0, #T_03b26_row16_col1, #T_03b26_row16_col2, #T_03b26_row16_col3, #T_03b26_row16_col4, #T_03b26_row16_col5, #T_03b26_row16_col6, #T_03b26_row17_col0, #T_03b26_row17_col1, #T_03b26_row17_col2, #T_03b26_row17_col3, #T_03b26_row17_col4, #T_03b26_row17_col5, #T_03b26_row17_col6, #T_03b26_row18_col0, #T_03b26_row18_col1, #T_03b26_row18_col2, #T_03b26_row18_col3, #T_03b26_row18_col4, #T_03b26_row18_col5, #T_03b26_row18_col6, #T_03b26_row19_col0, #T_03b26_row19_col1, #T_03b26_row19_col2, #T_03b26_row19_col3, #T_03b26_row19_col4, #T_03b26_row19_col5, #T_03b26_row19_col6, #T_03b26_row20_col0, #T_03b26_row20_col1, #T_03b26_row20_col2, #T_03b26_row20_col3, #T_03b26_row20_col4, #T_03b26_row20_col5, #T_03b26_row20_col6 {
#   text-align: left;
# }
# #T_03b26_row0_col2, #T_03b26_row0_col3, #T_03b26_row10_col1, #T_03b26_row10_col4, #T_03b26_row10_col5, #T_03b26_row10_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_03b26_row0_col7, #T_03b26_row2_col7, #T_03b26_row3_col7, #T_03b26_row4_col7, #T_03b26_row5_col7, #T_03b26_row6_col7, #T_03b26_row7_col7, #T_03b26_row8_col7, #T_03b26_row9_col7, #T_03b26_row10_col7, #T_03b26_row11_col7, #T_03b26_row12_col7, #T_03b26_row13_col7, #T_03b26_row14_col7, #T_03b26_row15_col7, #T_03b26_row16_col7, #T_03b26_row17_col7, #T_03b26_row18_col7, #T_03b26_row19_col7, #T_03b26_row20_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_03b26_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_03b26" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03b26_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_03b26_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_03b26_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_03b26_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_03b26_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_03b26_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_03b26_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_03b26_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03b26_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_03b26_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_03b26_row0_col1" class="data row0 col1" >104.0836</td>
#       <td id="T_03b26_row0_col2" class="data row0 col2" >535559.2710</td>
#       <td id="T_03b26_row0_col3" class="data row0 col3" >507.4430</td>
#       <td id="T_03b26_row0_col4" class="data row0 col4" >0.8020</td>
#       <td id="T_03b26_row0_col5" class="data row0 col5" >2.0713</td>
#       <td id="T_03b26_row0_col6" class="data row0 col6" >16.0148</td>
#       <td id="T_03b26_row0_col7" class="data row0 col7" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_03b26_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_03b26_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_03b26_row1_col1" class="data row1 col1" >105.5871</td>
#       <td id="T_03b26_row1_col2" class="data row1 col2" >953077.8251</td>
#       <td id="T_03b26_row1_col3" class="data row1 col3" >620.4166</td>
#       <td id="T_03b26_row1_col4" class="data row1 col4" >0.8055</td>
#       <td id="T_03b26_row1_col5" class="data row1 col5" >1.8602</td>
#       <td id="T_03b26_row1_col6" class="data row1 col6" >12.2131</td>
#       <td id="T_03b26_row1_col7" class="data row1 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_03b26_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_03b26_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_03b26_row2_col1" class="data row2 col1" >106.4108</td>
#       <td id="T_03b26_row2_col2" class="data row2 col2" >959132.6126</td>
#       <td id="T_03b26_row2_col3" class="data row2 col3" >622.0066</td>
#       <td id="T_03b26_row2_col4" class="data row2 col4" >0.8056</td>
#       <td id="T_03b26_row2_col5" class="data row2 col5" >1.8359</td>
#       <td id="T_03b26_row2_col6" class="data row2 col6" >12.2269</td>
#       <td id="T_03b26_row2_col7" class="data row2 col7" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_03b26_level0_row3" class="row_heading level0 row3" >ard</th>
#       <td id="T_03b26_row3_col0" class="data row3 col0" >Automatic Relevance Determination</td>
#       <td id="T_03b26_row3_col1" class="data row3 col1" >119.2777</td>
#       <td id="T_03b26_row3_col2" class="data row3 col2" >1013821.9247</td>
#       <td id="T_03b26_row3_col3" class="data row3 col3" >632.5533</td>
#       <td id="T_03b26_row3_col4" class="data row3 col4" >0.7962</td>
#       <td id="T_03b26_row3_col5" class="data row3 col5" >2.0782</td>
#       <td id="T_03b26_row3_col6" class="data row3 col6" >17.0685</td>
#       <td id="T_03b26_row3_col7" class="data row3 col7" >0.1340</td>
#     </tr>
#     <tr>
#       <th id="T_03b26_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_03b26_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_03b26_row4_col1" class="data row4 col1" >108.9003</td>
#       <td id="T_03b26_row4_col2" class="data row4 col2" >1004051.1584</td>
#       <td id="T_03b26_row4_col3" class="data row4 col3" >632.6189</td>
#       <td id="T_03b26_row4_col4" class="data row4 col4" >0.8017</td>
#       <td id="T_03b26_row4_col5" class="data row4 col5" >1.8961</td>
#       <td id="T_03b26_row4_col6" class="data row4 col6" >13.4473</td>
#       <td id="T_03b26_row4_col7" class="data row4 col7" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_03b26_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_03b26_row5_col0" class="data row5 col0" >Lasso L
# Processing:   0%|          | 0/89 [00:00<?, ?it/s]

# %%
import sys
print(sys.version)
# Out:
# 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]

# %%
# Print the best model
print(best_model)
# Out:
# OrthogonalMatchingPursuit()

# %%
# prompt: quero avaliar o best_model

# Evaluate the best model
evaluate_model(best_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # prompt: quero avaliar o best_model
#       2
#       3 # Evaluate the best model
# ----> 4 evaluate_model(best_model)
#
# NameError: name 'evaluate_model' is not defined

# %%
# To make predictions using the best model
# predictions = predict_model(best_model, data=dataset_agrupado) # Use unseen data for actual predictions
# print(predictions)
