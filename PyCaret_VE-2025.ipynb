# %%
import pandas as pd

caminho = r"C:\Users\user\PrevisãoVE2025\dados_VEs_porMunicipio2025.csv"
dataset = pd.read_csv(caminho, sep=',', dtype={"Cod_municipio": "int64"})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 4
#       1 import pandas as pd
#       3 caminho = r"C:\Users\user\PrevisãoVE2025\dados_VEs_porMunicipio2025.csv"
# ----> 4 dataset = pd.read_csv(caminho, sep=',', dtype={"Cod_municipio": "int64"})
#
# File c:\Users\Mariana\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)    944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Mariana\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Mariana\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Mariana\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\Mariana\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\user\\PrevisãoVE2025\\dados_VEs_porMunicipio2025.csv'

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Nome_UF                          14640 non-null  object
#  1   Nome_Município                   14640 non-null  object
#  2   Tipo_de_VE                       14640 non-null  object
#  3   Qtd. Veículos                    14640 non-null  int64
#  4   Cod_municipio                    14640 non-null  int64
#  5   Ano                              14640 non-null  int64
#  6   Potencia_instalada_fotovoltaica  14640 non-null  object
#  7   Tarifa_eletrica                  14640 non-null  object
#  8   Densidade_demo                   14640 non-null  float64
#  9   Frota                            14640 non-null  float64
#  10  Num_medio_salariosMin            14640 non-null  float64
#  11  Num_empregados                   14640 non-null  int64
#  12  Num_empresas                     14640 non-null  int64
#  13  PIB                              14640 non-null  object
#  14  Populacao                        14640 non-null  float64
#  15  Area                             14640 non-null  float64
#  16  IDH_educacao                     14640 non-null  float64
#  17  IDH_saude                        14640 non-null  float64
#  18  IDH_renda                        14640 non-null  float64
#  19  Educacao_superior                14640 non-null  float64
#  20  Irradiancia                      14640 non-null  float64
#  21  Num_familias                     14640 non-null  float64
#  22  Verticalizacao_cidades           14640 non-null  object
#  23  Familias_area_rural              14640 non-null  object
#  24  Casas_proprias                   14640 non-null  object
#  25  Casas_alugadas                   14640 non-null  object
#  26  Residentes_por_familia           14640 non-null  float64
#  27  Familias_mais_3_salarios         14640 non-null  object
# dtypes: float64(12), int64(5), object(11)
# memory usage: 3.1+ MB

# %%
dataset.columns
# Out:
# Index(['Nome_UF', 'Nome_Município', 'Tipo_de_VE', 'Qtd. Veículos',
#        'Cod_municipio', 'Ano', 'Potencia_instalada_fotovoltaica',
#        'Tarifa_eletrica', 'Densidade_demo', 'Frota', 'Num_medio_salariosMin',
#        'Num_empregados', 'Num_empresas', 'PIB', 'Populacao', 'Area',
#        'IDH_educacao', 'IDH_saude', 'IDH_renda', 'Educacao_superior',
#        'Irradiancia', 'Num_familias', 'Verticalizacao_cidades',
#        'Familias_area_rural', 'Casas_proprias', 'Casas_alugadas',
#        'Residentes_por_familia', 'Familias_mais_3_salarios'],
#       dtype='object')

# %%
dataset[dataset['PIB'] == '#DIV/0!'] # razão pela qual o PIB foi interpretado como object e não como numérico
# Out:
#                   Nome_UF Nome_Município                Tipo_de_VE  \
# 13399  MATO GROSSO DO SUL      FIGUEIRAO           DIESEL/ELETRICO
# 13400  MATO GROSSO DO SUL      FIGUEIRAO    ELETRICO/FONTE EXTERNA
# 13401  MATO GROSSO DO SUL      FIGUEIRAO  GASOLINA/ALCOOL/ELETRICO
# 13402  MATO GROSSO DO SUL      FIGUEIRAO           HIBRIDO PLUG-IN
#
#        Qtd. Veículos  Cod_municipio   Ano Potencia_instalada_fotovoltaica  \
# 13399              1        5003900  2025                          806.02
# 13400              1        5003900  2025                          806.02
# 13401              1        5003900  2025                          806.02
# 13402              1        5003900  2025                          806.02
#
#       Tarifa_eletrica  Densidade_demo   Frota  ...  IDH_renda  \
# 13399   8.733.224.036            0.73  1456.0  ...      677.0
# 13400   8.733.224.036            0.73  1456.0  ...      677.0
# 13401   8.733.224.036            0.73  1456.0  ...      677.0
# 13402   8.733.224.036            0.73  1456.0  ...      677.0
#
#        Educacao_superior  Irradiancia Num_familias  Verticalizacao_cidades  \
# 13399               36.0       5233.0       1363.0                 733.676
# 13400               36.0       5233.0       1363.0                 733.676
# 13401               36.0       5233.0       1363.0                 733.676
# 13402               36.0       5233.0       1363.0                 733.676
#
#        Familias_area_rural  Casas_proprias  Casas_alugadas  \
# 13399          428.466.618     415.260.455       8.217.168
# 13400          428.466.618     415.260.455       8.217.168
# 13401          428.466.618     415.260.455       8.217.168
# 13402          428.466.618     415.260.455       8.217.168
#
#        Residentes_por_familia  Familias_mais_3_salarios
# 13399                    2.59                29.347.029
# 13400                    2.59                29.347.029
# 13401                    2.59                29.347.029
# 13402                    2.59                29.347.029
#
# [4 rows x 28 columns]

# %%
# prompt: coloque o valor 46773.62 como o PIB do município de código 5003900

import pandas as pd
# It looks like there is an issue with assignment. Let's try using .loc to set the value.
# We also need to ensure the 'PIB' column is of a numeric type before assigning a float.
# Let's first convert the 'PIB' column to numeric, handling errors by coercing to NaN,
# and then fill the specific value using .loc
# Before converting, let's replace the '#DIV/0!' string with a value that can be coerced to NaN
dataset['PIB'] = dataset['PIB'].replace('#DIV/0!', pd.NA)

# Now convert the 'PIB' column to numeric
dataset['PIB'] = pd.to_numeric(dataset['PIB'], errors='coerce')

# Use .loc to assign the value based on the condition
dataset.loc[dataset['Cod_municipio'] == 5003900, 'PIB'] = 46773.62  # PIB de 2021 pelo IBGE que peguei no site.

# %%
dataset[dataset['Cod_municipio'] == 5003900]['PIB']
# Out:
# 13399    46773.62
# 13400    46773.62
# 13401    46773.62
# 13402    46773.62
# Name: PIB, dtype: float64

# %%
dataset.info() # agora sim, a princípio, todas as features interpretadas com o tipo correto de dado.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Nome_UF                          14640 non-null  object
#  1   Nome_Município                   14640 non-null  object
#  2   Tipo_de_VE                       14640 non-null  object
#  3   Qtd. Veículos                    14640 non-null  int64
#  4   Cod_municipio                    14640 non-null  int64
#  5   Ano                              14640 non-null  int64
#  6   Potencia_instalada_fotovoltaica  14640 non-null  object
#  7   Tarifa_eletrica                  14640 non-null  object
#  8   Densidade_demo                   14640 non-null  float64
#  9   Frota                            14640 non-null  float64
#  10  Num_medio_salariosMin            14640 non-null  float64
#  11  Num_empregados                   14640 non-null  int64
#  12  Num_empresas                     14640 non-null  int64
#  13  PIB                              14640 non-null  float64
#  14  Populacao                        14640 non-null  float64
#  15  Area                             14640 non-null  float64
#  16  IDH_educacao                     14640 non-null  float64
#  17  IDH_saude                        14640 non-null  float64
#  18  IDH_renda                        14640 non-null  float64
#  19  Educacao_superior                14640 non-null  float64
#  20  Irradiancia                      14640 non-null  float64
#  21  Num_familias                     14640 non-null  float64
#  22  Verticalizacao_cidades           14640 non-null  object
#  23  Familias_area_rural              14640 non-null  object
#  24  Casas_proprias                   14640 non-null  object
#  25  Casas_alugadas                   14640 non-null  object
#  26  Residentes_por_familia           14640 non-null  float64
#  27  Familias_mais_3_salarios         14640 non-null  object
# dtypes: float64(13), int64(5), object(10)
# memory usage: 3.1+ MB

# %%
# prompt: transforme o dataset de forma que cada linha seja um município e a quantidade de veículos represente a soma de todos os tipos de veículos, mantenha todas as colunas.

# Agrupar por município e somar a quantidade de veículos
dataset_agrupado = dataset.groupby('Cod_municipio').agg({ # funciona bem porque cada município tem um código único do IBGE
    'Nome_UF': 'first',
    'Nome_Município': 'first',      # Pq eu posso pegar a primeira ocorrência de todos, exceto o Cod_municipio?
    'Tipo_de_VE': 'first',          # Pois as demais colunas tem dados repetidos em função do Tipo_de_VE. Estamos considerando todos os tipos como "eletrico"
    'Qtd. Veículos': 'sum', # soma as quantidade por City_Cod
    'Ano': 'first',
    'Potencia_instalada_fotovoltaica': 'first',
    'Tarifa_eletrica': 'first',
    'Densidade_demo': 'first',
    'Frota': 'first',
    'Num_medio_salariosMin': 'first',
    'Num_empregados': 'first',
    'Num_empresas': 'first',
    'PIB': 'first',
    'Populacao': 'first',
    'Area': 'first',
    'IDH_educacao': 'first',
    'IDH_saude': 'first',
    'IDH_renda': 'first',
    'Educacao_superior': 'first',
    'Irradiancia': 'first',
    'Num_familias': 'first',
    'Verticalizacao_cidades': 'first',
    'Familias_area_rural': 'first',
    'Casas_proprias': 'first',
    'Casas_alugadas': 'first',
    'Residentes_por_familia': 'first',
    'Familias_mais_3_salarios': 'first'
}).reset_index()

# Exibir o dataset transformado
print(dataset_agrupado.head())
dataset_agrupado.info()
# Out:
#    Cod_municipio   Nome_UF         Nome_Município              Tipo_de_VE  \
# 0        1100015  RONDONIA  ALTA FLORESTA D'OESTE  ELETRICO/FONTE EXTERNA
# 1        1100023  RONDONIA              ARIQUEMES         DIESEL/ELETRICO
# 2        1100031  RONDONIA                 CABIXI       GASOLINA/ELETRICO
# 3        1100049  RONDONIA                 CACOAL                ELETRICO
# 4        1100056  RONDONIA             CEREJEIRAS  ELETRICO/FONTE EXTERNA
#
#    Qtd. Veículos   Ano Potencia_instalada_fotovoltaica Tarifa_eletrica  \
# 0             11  2025                         3467.06   6.865.558.129
# 1            217  2025                        28751.08   6.865.558.129
# 2              1  2025                         1322.32   6.865.558.129
# 3            178  2025                        25024.72   6.865.558.129
# 4             15  2025                         4588.86   6.865.558.129
#
#    Densidade_demo    Frota  ...  IDH_renda  Educacao_superior  Irradiancia  \
# 0            3.04  16100.0  ...     657.00               36.0       4635.0
# 1           21.88  82721.0  ...     716.00               39.0       4494.0
# 2            4.07   4039.0  ...       0.65               38.0       4795.0
# 3           22.91  75559.0  ...     727.00               47.0       4622.0
# 4            5.71  13012.0  ...     688.00               48.0       4767.0
#
#    Num_familias  Verticalizacao_cidades  Familias_area_rural  Casas_proprias  \
# 0        7695.0               1.689.409          375.048.733     697.076.023
# 1       34768.0              62.068.569          126.754.487      51.590.543
# 2        1967.0               1.525.165          456.532.791     764.616.167
# 3       31917.0               7.898.612          162.859.918     507.660.494
# 4        5873.0               9.705.432          106.419.207     674.101.822
#
#    Casas_alugadas  Residentes_por_familia  Familias_mais_3_salarios
# 0     106.822.612                    2.79                30.669.266
# 1     182.984.353                    2.77                53.324.896
# 2      75.749.873                    2.72                30.503.305
# 3     167.308.958                    2.71                52.667.857
# 4     132.640.899                    2.69                44.951.473
#
# [5 rows x 28 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4483 entries, 0 to 4482
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Cod_municipio                    4483 non-null   int64
#  1   Nome_UF                          4483 non-null   object
#  2   Nome_Município                   4483 non-null   object
#  3   Tipo_de_VE                       4483 non-null   object
#  4   Qtd. Veículos                    4483 non-null   int64
#  5   Ano                              4483 non-null   int64
#  6   Potencia_instalada_fotovoltaica  4483 non-null   object
#  7   Tarifa_eletrica                  4483 non-null   object
#  8   Densidade_demo                   4483 non-null   float64
#  9   Frota                            4483 non-null   float64
#  10  Num_medio_salariosMin            4483 non-null   float64
#  11  Num_empregados                   4483 non-null   int64
#  12  Num_empresas                     4483 non-null   int64
#  13  PIB                              4483 non-null   float64
#  14  Populacao                        4483 non-null   float64
#  15  Area                             4483 non-null   float64
#  16  IDH_educacao                     4483 non-null   float64
#  17  IDH_saude                        4483 non-null   float64
#  18  IDH_renda                        4483 non-null   float64
#  19  Educacao_superior                4483 non-null   float64
#  20  Irradiancia                      4483 non-null   float64
#  21  Num_familias                     4483 non-null   float64
#  22  Verticalizacao_cidades           4483 non-null   object
#  23  Familias_area_rural              4483 non-null   object
#  24  Casas_proprias                   4483 non-null   object
#  25  Casas_alugadas                   4483 non-null   object
#  26  Residentes_por_familia           4483 non-null   float64
#  27  Familias_mais_3_salarios         4483 non-null   object
# dtypes: float64(13), int64(5), object(10)
# memory usage: 980.8+ KB

# %%
# a partir deste ponto é que eu posso começar a brincar  para treinar os algoritmos.
# Afinal, é neste ponto que o dataset está pronto, ou seja, cada linha está por município.

# %%
# %pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from pycaret) (9.10.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (8.1.8)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (4.67.3)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (2.0.7)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (0.14.1)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (0.64.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (2.32.5)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from pycaret) (7.2.2)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (8.7.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (6.6.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (0.14.6)
# Requirement already satisfied: sktime==0.26.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\mariana\appdata\roaming\python\python311\site-packages (from sktime==0.26.0->pycaret) (26.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (0.1.5)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.6.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipython>=5.5.0->pycaret) (4.15.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.16)
# Requirement already satisfied: choreographer>=1.1.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from kaleido>=0.2.1->pycaret) (1.2.1)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from kaleido>=0.2.1->pycaret) (3.11.7)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.8.0->pycaret) (12.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from nbformat>=4.2.0->pycaret) (5.9.1)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from numba>=0.55.0->pycaret) (0.46.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.2.0->pycaret) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.2.0->pycaret) (2025.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from plotly>=5.14.0->pycaret) (2.17.0)
# Requirement already satisfied: dash>=2.11.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (4.0.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.2.4)
# Requirement already satisfied: urllib3 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.6.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pmdarima>=2.0.4->pycaret) (65.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27.1->pycaret) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27.1->pycaret) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27.1->pycaret) (2026.2.25)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from choreographer>=1.1.1->kaleido>=0.2.1->pycaret) (3.20.2)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.3)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.6)
# Requirement already satisfied: retrying in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\mariana\appdata\roaming\python\python311\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from jedi>=0.18.1->ipython>=5.5.0->pycaret) (0.8.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.9.2)
# Requirement already satisfied: wcwidth in c:\users\mariana\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.6.0)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (9.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\mariana\appdata\roaming\python\python311\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\mariana\appdata\roaming\python\python311\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (0.2.3)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\mariana\appdata\local\programs\python\python311\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **Faz sentido remover Nome_UF? Provavelmente não. É recomendado manter.**
#
# - Motivo: A UF (Estado) é uma variável categórica com um número gerenciável de categorias (27 no Brasil). Fatores como políticas estaduais, desenvolvimento econômico regional, densidade populacional e infraestrutura podem variar significativamente entre UFs e influenciar a quantidade de veículos elétricos.
#
# - **atualização:** fiz um teste deixando Nome_UF acontece um One_hot_enconding e passamos a ter 27 variáveis. O Distrito Federal (por ser estado e município) acaba dominando, o que não faz sentido. **Portanto, decidi remover a coluna Nome_UF.**

# %%
from pycaret.regression import *

# Setup PyCaret for regression
s = setup(dataset_agrupado,
          target = 'Qtd. Veículos',
          ignore_features = ['Nome_UF', 'Cod_municipio', 'Nome_Município', 'Tipo_de_VE', 'Ano'],
          #categorical_features = ['Nome_UF'], # Ensure Nome_UF is treated as categorical
          polynomial_features = False,
          polynomial_degree = 2,
          # ignore_low_variance = True, # Useful for numerical features with little variance
          remove_multicollinearity = True, # Useful to remove highly correlated features
          multicollinearity_threshold = 0.9,
          fold_strategy = 'kfold',
          fold = 10, # Default number of folds
          n_jobs = -1, # Use all available cores
          session_id = 123,
          log_experiment = False,
          experiment_name = 'regression_experiment',
          use_gpu = False, # Set to True if you have a compatible GPU
          profile = True, # Generate a profiling report to see memory and CPU usage
          # memory = False, # Optimize memory usage
          # verbose = True, # Display verbose output during setup
          # version = False, # Display PyCaret version
          # early_stopping = False,
          # early_stopping_max_rounds = 10,
          # early_stopping_method = 'caret',
          # calibrate = False,
          # calibrate_method = 'isotonic',
          # fit_kwargs = None,
          # transform_kwargs = None,
          preprocess = True, # Ensure preprocessing is enabled
          # low_variance_threshold = 0.01,
          # numeric_imputation = 'mean',
          # categorical_imputation = 'mode',
          normalize = False,
          # normalize_method = 'zscore',
          # transform_target = False,
          # transform_target_method = 'box-cox',
          # data_split_is_greater_than = 1000,
          # handle_missing_values = True,
          # missing_values_symbol = 'NaN',
          # Iterative Imputation
          # iterative_imputation_iterator = 'lightgbm',
          # iterative_imputation_iters = 10,
          # iterative_imputation_random_state = 123,
          # iterative_imputation_order = 'roman',
          # iterative_imputation_add_indicator = False,
          # iterative_imputation_imputer_list = None,
          max_encoding_ohe = 27 # Set the one-hot encoding limit
          )

# Compare models including specific algorithms
best_model = compare_models(include=['lr', 'lasso', 'ridge', 'en', 'lar', 'llar', 'omp', 'br', 'ard', 'par', 'kr', 'svm', 'knn', 'dt', 'rf', 'et', 'ada', 'gbr', 'mlp', 'xgboost', 'lightgbm'],
                           # Add the specific algorithms you want to include
                           # MLP is 'mlp' (Neural Network)
                           # SVR is 'svm'
                           # XGBoost is 'xgboost'
                           # Other models are added for a more comprehensive comparison
                           # 'lr' (Linear Regression), 'lasso' (Lasso Regression), 'ridge' (Ridge Regression), 'en' (Elastic Net), 'lar' (Least Angle Regression), 'llar' (Lasso Least Angle Regression), 'omp' (Orthogonal Matching Pursuit), 'br' (Bayesian Ridge), 'ard' (Automatic Relevance Determination), 'par' (Passive Aggressive Regressor), 'hr' (Huber Regressor), 'kr' (Kernel Ridge), 'knn' (K Neighbors Regressor), 'dt' (Decision Tree Regressor), 'rf' (Random Forest Regressor), 'et' (Extra Trees Regressor), 'ada' (AdaBoost Regressor), 'gbr' (Gradient Boosting Regressor), 'lightgbm' (Light Gradient Boosting Machine), 'catboost' (CatBoost Regressor)
                           sort = 'RMSE') # Sort by Root Mean Squared Error
# Out:
# <style type="text/css">
# #T_d9f62_row10_col1, #T_d9f62_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d9f62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9f62_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d9f62_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9f62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9f62_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d9f62_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9f62_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d9f62_row1_col1" class="data row1 col1" >Qtd. Veículos</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9f62_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d9f62_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9f62_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d9f62_row3_col1" class="data row3 col1" >(4483, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9f62_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d9f62_row4_col1" class="data row4 col1" >(4483, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9f62_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d9f62_row5_col1" class="data row5 col1" >(3138, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9f62_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d9f62_row6_col1" class="data row6 col1" >(1345, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9f62_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_d9f62_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9f62_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_d9f62_row8_col1" class="data row8 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9f62_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_d9f62_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d9f62_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_d9f62_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d9f62_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_d9f62_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d9f62_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_d9f62_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d9f62_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_d9f62_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d9f62_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_d9f62_row14_col1" class="data row14 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d9f62_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_d9f62_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d9f62_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_d9f62_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d9f62_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_d9f62_row17_col1" class="data row17 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d9f62_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_d9f62_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d9f62_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_d9f62_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d9f62_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_d9f62_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d9f62_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_d9f62_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d9f62_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_d9f62_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d9f62_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_d9f62_row23_col1" class="data row23 col1" >regression_experiment</td>
#     </tr>
#     <tr>
#       <th id="T_d9f62_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d9f62_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_d9f62_row24_col1" class="data row24 col1" >cdac</td>
#     </tr>
#   </tbody>
# </table>
# Loading profile... Please Wait!
# Profiler Failed. No output to show, continue with modeling.
# <style type="text/css">
# #T_c89f0 th {
#   text-align: left;
# }
# #T_c89f0_row0_col0, #T_c89f0_row0_col1, #T_c89f0_row0_col4, #T_c89f0_row0_col5, #T_c89f0_row0_col6, #T_c89f0_row1_col0, #T_c89f0_row1_col1, #T_c89f0_row1_col2, #T_c89f0_row1_col3, #T_c89f0_row1_col4, #T_c89f0_row1_col5, #T_c89f0_row1_col6, #T_c89f0_row2_col0, #T_c89f0_row2_col1, #T_c89f0_row2_col2, #T_c89f0_row2_col3, #T_c89f0_row2_col4, #T_c89f0_row2_col5, #T_c89f0_row2_col6, #T_c89f0_row3_col0, #T_c89f0_row3_col1, #T_c89f0_row3_col2, #T_c89f0_row3_col3, #T_c89f0_row3_col5, #T_c89f0_row3_col6, #T_c89f0_row4_col0, #T_c89f0_row4_col1, #T_c89f0_row4_col2, #T_c89f0_row4_col3, #T_c89f0_row4_col4, #T_c89f0_row4_col5, #T_c89f0_row4_col6, #T_c89f0_row5_col0, #T_c89f0_row5_col1, #T_c89f0_row5_col2, #T_c89f0_row5_col3, #T_c89f0_row5_col4, #T_c89f0_row5_col5, #T_c89f0_row5_col6, #T_c89f0_row6_col0, #T_c89f0_row6_col1, #T_c89f0_row6_col2, #T_c89f0_row6_col3, #T_c89f0_row6_col4, #T_c89f0_row6_col5, #T_c89f0_row6_col6, #T_c89f0_row7_col0, #T_c89f0_row7_col1, #T_c89f0_row7_col2, #T_c89f0_row7_col3, #T_c89f0_row7_col4, #T_c89f0_row7_col5, #T_c89f0_row7_col6, #T_c89f0_row8_col0, #T_c89f0_row8_col1, #T_c89f0_row8_col2, #T_c89f0_row8_col3, #T_c89f0_row8_col4, #T_c89f0_row8_col5, #T_c89f0_row8_col6, #T_c89f0_row9_col0, #T_c89f0_row9_col1, #T_c89f0_row9_col2, #T_c89f0_row9_col3, #T_c89f0_row9_col4, #T_c89f0_row9_col5, #T_c89f0_row9_col6, #T_c89f0_row10_col0, #T_c89f0_row10_col1, #T_c89f0_row10_col2, #T_c89f0_row10_col3, #T_c89f0_row10_col4, #T_c89f0_row10_col5, #T_c89f0_row10_col6, #T_c89f0_row11_col0, #T_c89f0_row11_col1, #T_c89f0_row11_col2, #T_c89f0_row11_col3, #T_c89f0_row11_col4, #T_c89f0_row11_col5, #T_c89f0_row11_col6, #T_c89f0_row12_col0, #T_c89f0_row12_col1, #T_c89f0_row12_col2, #T_c89f0_row12_col3, #T_c89f0_row12_col4, #T_c89f0_row12_col5, #T_c89f0_row12_col6, #T_c89f0_row13_col0, #T_c89f0_row13_col1, #T_c89f0_row13_col2, #T_c89f0_row13_col3, #T_c89f0_row13_col4, #T_c89f0_row13_col5, #T_c89f0_row13_col6, #T_c89f0_row14_col0, #T_c89f0_row14_col1, #T_c89f0_row14_col2, #T_c89f0_row14_col3, #T_c89f0_row14_col4, #T_c89f0_row14_col5, #T_c89f0_row14_col6, #T_c89f0_row15_col0, #T_c89f0_row15_col1, #T_c89f0_row15_col2, #T_c89f0_row15_col3, #T_c89f0_row15_col4, #T_c89f0_row15_col5, #T_c89f0_row15_col6, #T_c89f0_row16_col0, #T_c89f0_row16_col1, #T_c89f0_row16_col2, #T_c89f0_row16_col3, #T_c89f0_row16_col4, #T_c89f0_row16_col5, #T_c89f0_row16_col6, #T_c89f0_row17_col0, #T_c89f0_row17_col1, #T_c89f0_row17_col2, #T_c89f0_row17_col3, #T_c89f0_row17_col4, #T_c89f0_row17_col5, #T_c89f0_row17_col6, #T_c89f0_row18_col0, #T_c89f0_row18_col1, #T_c89f0_row18_col2, #T_c89f0_row18_col3, #T_c89f0_row18_col4, #T_c89f0_row18_col5, #T_c89f0_row18_col6, #T_c89f0_row19_col0, #T_c89f0_row19_col2, #T_c89f0_row19_col3, #T_c89f0_row19_col4, #T_c89f0_row20_col0, #T_c89f0_row20_col1, #T_c89f0_row20_col2, #T_c89f0_row20_col3, #T_c89f0_row20_col4, #T_c89f0_row20_col5, #T_c89f0_row20_col6 {
#   text-align: left;
# }
# #T_c89f0_row0_col2, #T_c89f0_row0_col3, #T_c89f0_row3_col4, #T_c89f0_row19_col1, #T_c89f0_row19_col5, #T_c89f0_row19_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c89f0_row0_col7, #T_c89f0_row1_col7, #T_c89f0_row2_col7, #T_c89f0_row3_col7, #T_c89f0_row4_col7, #T_c89f0_row5_col7, #T_c89f0_row6_col7, #T_c89f0_row7_col7, #T_c89f0_row8_col7, #T_c89f0_row9_col7, #T_c89f0_row10_col7, #T_c89f0_row11_col7, #T_c89f0_row13_col7, #T_c89f0_row14_col7, #T_c89f0_row15_col7, #T_c89f0_row16_col7, #T_c89f0_row17_col7, #T_c89f0_row18_col7, #T_c89f0_row19_col7, #T_c89f0_row20_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c89f0_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c89f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c89f0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c89f0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c89f0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c89f0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c89f0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c89f0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c89f0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c89f0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c89f0_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_c89f0_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_c89f0_row0_col1" class="data row0 col1" >224.4650</td>
#       <td id="T_c89f0_row0_col2" class="data row0 col2" >1698975.5965</td>
#       <td id="T_c89f0_row0_col3" class="data row0 col3" >1028.0045</td>
#       <td id="T_c89f0_row0_col4" class="data row0 col4" >0.0456</td>
#       <td id="T_c89f0_row0_col5" class="data row0 col5" >2.8854</td>
#       <td id="T_c89f0_row0_col6" class="data row0 col6" >39.1051</td>
#       <td id="T_c89f0_row0_col7" class="data row0 col7" >0.0930</td>
#     </tr>
#     <tr>
#       <th id="T_c89f0_level0_row1" class="row_heading level0 row1" >mlp</th>
#       <td id="T_c89f0_row1_col0" class="data row1 col0" >MLP Regressor</td>
#       <td id="T_c89f0_row1_col1" class="data row1 col1" >220.0862</td>
#       <td id="T_c89f0_row1_col2" class="data row1 col2" >2654001.8313</td>
#       <td id="T_c89f0_row1_col3" class="data row1 col3" >1231.8505</td>
#       <td id="T_c89f0_row1_col4" class="data row1 col4" >-0.0034</td>
#       <td id="T_c89f0_row1_col5" class="data row1 col5" >2.7265</td>
#       <td id="T_c89f0_row1_col6" class="data row1 col6" >36.0636</td>
#       <td id="T_c89f0_row1_col7" class="data row1 col7" >0.4870</td>
#     </tr>
#     <tr>
#       <th id="T_c89f0_level0_row2" class="row_heading level0 row2" >par</th>
#       <td id="T_c89f0_row2_col0" class="data row2 col0" >Passive Aggressive Regressor</td>
#       <td id="T_c89f0_row2_col1" class="data row2 col1" >272.9772</td>
#       <td id="T_c89f0_row2_col2" class="data row2 col2" >2768449.0510</td>
#       <td id="T_c89f0_row2_col3" class="data row2 col3" >1286.9555</td>
#       <td id="T_c89f0_row2_col4" class="data row2 col4" >-0.1952</td>
#       <td id="T_c89f0_row2_col5" class="data row2 col5" >2.8027</td>
#       <td id="T_c89f0_row2_col6" class="data row2 col6" >45.7420</td>
#       <td id="T_c89f0_row2_col7" class="data row2 col7" >0.0940</td>
#     </tr>
#     <tr>
#       <th id="T_c89f0_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_c89f0_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#       <td id="T_c89f0_row3_col1" class="data row3 col1" >154.8750</td>
#       <td id="T_c89f0_row3_col2" class="data row3 col2" >3558266.0671</td>
#       <td id="T_c89f0_row3_col3" class="data row3 col3" >1288.3714</td>
#       <td id="T_c89f0_row3_col4" class="data row3 col4" >0.2082</td>
#       <td id="T_c89f0_row3_col5" class="data row3 col5" >1.5016</td>
#       <td id="T_c89f0_row3_col6" class="data row3 col6" >7.2178</td>
#       <td id="T_c89f0_row3_col7" class="data row3 col7" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_c89f0_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_c89f0_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_c89f0_row4_col1" class="data row4 col1" >164.1207</td>
#       <td id="T_c89f0_row4_col2" class="data row4 col2" >3249342.4898</td>
#       <td id="T_c89f0_row4_col3" class="data row4 col3" >1307.4109</td>
#       <td id="T_c89f0_row4_col4" class="data row4 col4" >0.0427</td>
#       <td id="T_c89f0_row4_col5" class="data row4 col5" >2.1677</td>
#       <td id="T_c89f0_row4_col6" class="data row4 col6" >13.4899</td>
#       <td id="T_c89f0_row4_col7" class="data row4 col7" >0.1060</td>
#     </tr>
#     <tr>
#       <th id="T_c89f0_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_c89f0_row5_col0" class="data row5 col0" >Light

# %%
import sys
print(sys.version)
# Out:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]

# %%
# Print the best model
print(best_model)
# Out:
# OrthogonalMatchingPursuit()

# %%
# prompt: quero avaliar o best_model

# Evaluate the best model
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# To make predictions using the best model
# predictions = predict_model(best_model, data=dataset_agrupado) # Use unseen data for actual predictions
# print(predictions)
